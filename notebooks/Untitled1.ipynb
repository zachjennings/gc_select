# %%
# %matplotlib inline

import matplotlib.pyplot as plt

import densityGC
import densityFG
import gcSampler
import numpy as np
import scipy
import triangle
import colorKDE

reload(densityGC)
reload(densityFG)
reload(gcSampler)
# Out:
# <module 'gcSampler' from 'gcSampler.py'>

# %%
sampler = gcSampler.gcSampler(30,radial_profile='exponential',fractions=np.array([0.2,0.2,0.6]),fixed_cov=False,\
                             ellipticity=True,n_pop=2,red_lim=2.0,fg_type='sdss_empirical')

# %%
# %time sampler.runSampler(100,burn_steps=0)
# Out:
# f_gc median,  16 %, and  84 %  0.199964615371    0.199088006493    0.20094491251
# f_gc_2 median,  16 %, and  84 %  0.199967999492    0.199594636793    0.200327404334
# mu_gi_1 median,  16 %, and  84 %  1.08964654337    1.08864860784    1.09031000066
# mu_ri_1 median,  16 %, and  84 %  0.329064448992    0.328482827383    0.329693292623
# sig_gi_1 median,  16 %, and  84 %  0.00411954253489    0.00344313232503    0.00460766168207
# sig_ri_1 median,  16 %, and  84 %  0.00113157760216    0.000962725019265    0.00136427226742
# cov_1 median,  16 %, and  84 %  0.00182625950315    0.00156731738174    0.00208380060326
# mu_gi_2 median,  16 %, and  84 %  0.801514938985    0.801182232173    0.80184816658
# mu_ri_2 median,  16 %, and  84 %  0.20039294449    0.199688462772    0.200936583046
# sig_gi_2 median,  16 %, and  84 %  0.0236769755317    0.0229224658397    0.0243807427768
# sig_ri_2 median,  16 %, and  84 %  0.00304895172997    0.00278882021237    0.00338059432717
# ...

# %%
# %time sampler.fg.lnLike(sampler.data)
# Out:
# CPU times: user 94.3 ms, sys: 315 µs, total: 94.6 ms
# Wall time: 94.3 ms
# array([ -5.79664115,  -5.67272728,  -5.76659111,  -5.71738688,
#         -5.7792122 ,  -5.71048001,  -5.81318693,  -5.69777687,
#         -5.68396447,  -5.66044833,  -5.96465922,  -6.03042208,
#         -5.93080285,  -5.75547697,  -5.62511402,  -5.71743876,
#         -5.65813056,  -6.01109677,  -5.64117468,  -5.68255419,
#         -5.94772005,  -5.69815771,  -5.70585765,  -6.0018449 ,
#         -5.65983587,  -5.90074161,  -5.68890129,  -5.65736434,
#         -5.72673112,  -6.05780231,  -5.73303346,  -5.64611002,
#         -5.76776052,  -5.59153132,  -5.70641692,  -5.66010293,
#         -5.76971304,  -5.63343487,  -5.73936401,  -5.68329092,
#         -5.79835   ,  -5.69723035,  -5.66525397,  -5.69160623,
#         -5.86598412,  -5.71090619,  -5.99171014,  -5.82314512,
#         -5.65900743,  -5.70929691,  -5.77789553,  -6.11921054,
#         -5.63357349,  -5.72328241,  -5.78711072,  -5.77066996,
# ...
