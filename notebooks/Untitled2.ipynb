# %%
from astropy.io import fits
# Out:
# /Users/zach/astro/ureka/Ureka/variants/common/lib/python2.7/site-packages/IPython/kernel/__init__.py:13: ShimWarning: The `IPython.kernel` package has been deprecated. You should import from ipykernel or jupyter_client instead.
#   "You should import from ipykernel or jupyter_client instead.", ShimWarning)

# %%
the_file = fits.open('/Users/zach/N3628UCDspectrum.fits')

# %%
the_file[0].header
# Out:
# SIMPLE  =                    T / Fits standard
# BITPIX  =                  -32
# NAXIS   =                    2 / Number of axes
# NAXIS1  =                 4094
# NAXIS2  =                   10
# EXTEND  =                    T / File may contain extensions
# ORIGIN  = 'NOAO-IRAF FITS Image Kernel July 2003' / FITS file originator
# DATE    = '2014-03-24T04:44:36' / Date FITS file was generated
# IRAF-TLM= '2014-03-24T04:44:34' / Time of last modification
# OBJECT  = 'NGC3628_UCD (Flux) (Linear)'
# COMMENT   FITS (Flexible Image Transport System) format defined in Astronomy and
# COMMENT   Astrophysics Supplement Series v44/p363, v44/p371, v73/p359, v73/p365.
# COMMENT   Contact the NASA Science Office of Standards and Technology for the
# COMMENT   FITS Definition document #100 and other FITS information.
# COMMENT The following keywords came from KTL via watch_ccd
# TEMPDET =        -119.96702576
# UTBTEMP =           5.00000000
# UTBFANS = 'on      '
# ...
